# %% [markdown]
# ### TPC5: Aplicação para Gerir um Cinema
#
# Suponha que está a desenvolver uma aplicacão para gestão de um conjunto de salas de cinema de um centro comercial.
# Nesse centro comercial existem algumas salas de cinema (que poderão estar a exibir filmes ou não), cada sala tem uma determinada
# lotação, uma lista com a referência dos bilhetes vendidos (lugares ocupados; cada lugar é identificado por um número inteiro), e cada sala tem um filme associado.
#
# Considera a seguinte sugestão para o modelo dos cinemas:
# ```
# Cinema = [Sala]
# Sala = [nlugares, Vendidos, filme]
# nlugares = Int
# filme = String
# Vendidos = [Int]
# ```
#
# Que poderá ser usado num programa da seguinte forma:
# ```
# sala1 = (150, [], "Twilight")
# sala2 = (200, [], "Hannibal")
# cinema1 = []
# ...
# cinema1 = inserirSala(cinema1,sala1)
# cinema1 = inserirSala(cinema1,sala2)
# ...
# listar(cinema1)
# ...
#
# if(disponivel(cinema1, "Twilight", 17 )):
#   cinema1 = vendebilhete(cinema1, "Twilight", 17 )
# ...
# listardisponibilidades(cinema1)
# ...
# ```
#
# Especifique as funções utilizadas no exemplo:
#
# 1. `listar( cinema )` - que lista no monitor todos os filmes que estão em exibição nas salas do cinema passado como argumento;
# 2. `disponivel( cinema, filme, lugar )` - que dá como resultado **False** se o lugar lugar já estiver ocupado na sala onde o filme está a ser exibido e dará como resultado **True** se o inverso acontecer;
# 3. `vendebilhete( cinema, filme, lugar )` - que dá como resultado um novo cinema resultante de acrescentar o lugar à lista dos lugares ocupados, na sala onde está a ser exibido o filme;
# 4. `listardisponibilidades( cinema )` - que, para um dado cinema, lista no monitor para cada sala, o filme que está a ser exibido e o total de lugares disponíveis nessa sala (número de lugares na sala menos o número de lugares ocupados);
# 5. `inserirSala( cinema, sala )` - que acrescenta uma sala nova a um cinema (devendo verificar se a sala já existe);
# 6. Acrescente todas as outras funcionalidades que achar necessárias;
# 7. À semelhança do exercício 3, construa uma aplicação com um menu de interface para as operações.

# %%
#Cinema = [Sala]
#Sala = [filme, Vendidos, nº de lugares disp]
#nlugares = Int
#filme = String 
#Vendidos = [Int]

cinema = []


def inserirSala( cinema, s):
    cinema.append(s)
    return cinema

def listar(cinema):
    print ("------------ FILMES DISPONÍVEIS ------------")
    for s in cinema: 
        print("Nome:", s[0])
    

def disponivel(cinema, filme, lugar):
    cond = True 
    for s in cinema:
        if s[0] == filme: 
            if lugar in s[1]:
                cond = False
    if cond == True :
        print("\nO seu lugar está disponível!")
    if cond == False :
        print("\nO seu lugar não está disponível.")
    

def listardisponibilidades(cinema):
    for s in cinema :
        if filme == s[0]:
            x = s[2] - len(s[1]) 
    if x != 0 :
        print("\nO filme ", filme ," tem ", x ," lugares disponíveis.")
    if x == 0 :
        print("\nO filme não tem lugares disponíveis.")

def venderBilhete(cinema, filme, lugar):  
    for s in cinema:
        if s[0] == filme :
            if lugar not in s[1]:
                s[1].append(lugar)
    print("\nObrigado pela sua compra!\n O seu bilhete é o seguinte: \nFilme:", filme ,"|","Lugar:",lugar)

# %%
s1 = ["Twilight", [] , 120]
s2 = ["A Freira", [] , 90]
s3 = ["Barbie", [], 130]
s4 = ["Oppenheimer", [] , 125]
cinema = []
cinema = inserirSala(cinema, s1)
cinema = inserirSala(cinema, s2)
cinema = inserirSala(cinema, s3)
cinema = inserirSala(cinema, s4)


Menu = "Bom dia! Obrigado por escolher o Cinema XX, aqui estão os próximos passos: \n(1) Listar todos os filmes em exibição; \n(2) Verificar a disponibilidade da sala e do lugar; \n(3) Comprar bilhete, somente após verificar a disponibilidade; \n(4) Fechar o menu."
print(Menu)

n = int(input("Qual é a sua opção?"))

while n != 4: 

    if n == 1:
        print(listar(cinema))
        n = int(input("Qual é a sua opção?"))
        

    if n == 2:
        filme = input("Escolha o filme que deseja saber a disponibilidade.")
        print(listardisponibilidades(cinema))
        if print==("O filme não tem lugares disponíveis."):
            print("Terá que aguardar até a uma próxima sessão. Obrigado pela compreensão.")
        n = int(input("Qual é a sua opção?"))

    if n == 3: 
        filme = input("Escolha o filme que deseja ver.")
        lugar = int(input("Escolha o lugar que deseja.")) 
        print(disponivel(cinema, filme, lugar))
        if print != ("O seu lugar não está disponível."):
            cinema = venderBilhete(cinema, filme, lugar)
        n = int(input("Qual é a sua opção?"))

if n == 4 :
    print("Esperemos que o serviço tenha sido do seu agrado, até uma próxima!")
# Out:
# Bom dia! Obrigado por escolher o Cinema XX, aqui estão os próximos passos:
# (1) Listar todos os filmes em exibição;
# (2) Verificar a disponibilidade da sala e do lugar;
# (3) Comprar bilhete, somente após verificar a disponibilidade;
# (4) Fechar o menu.
# ------------ FILMES DISPONÍVEIS ------------
# Nome: Twilight
# Nome: A Freira
# Nome: Barbie
# Nome: Oppenheimer
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\carol\Desktop\Programação\TPC5.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/carol/Desktop/Programa%C3%A7%C3%A3o/TPC5.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> if n == 1:
#      <a href='vscode-notebook-cell:/c%3A/Users/carol/Desktop/Programa%C3%A7%C3%A3o/TPC5.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a>     print(listar(cinema))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/carol/Desktop/Programa%C3%A7%C3%A3o/TPC5.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a>     n = int(input("Qual é a sua opção?"))
#      <a href='vscode-notebook-cell:/c%3A/Users/carol/Desktop/Programa%C3%A7%C3%A3o/TPC5.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a> if n == 2:
#      <a href='vscode-notebook-cell:/c%3A/Users/carol/Desktop/Programa%C3%A7%C3%A3o/TPC5.ipynb#W2sZmlsZQ%3D%3D?line=24'>25</a>     filme = input("Escolha o filme que deseja saber a disponibilidade.")
#
# ValueError: invalid literal for int() with base 10: ''
