# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios
#
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
#FUNCIONALIDADES NÃO TRABALHADAS NA AULA
p1=[(1,7),(3.7,4),(5,3),(88,0)]
p2=[(2,2),(17,0)]
p3=[(7,4),(6,3),(1,2),(43,0)]
p4=[(1,4)]
p5=[(1,2)]
p6=[(1,3)]

#FICHEIRO DE TEXTO
def gravaPolinomio(fnome, polinomio):
    file = open(fnome, "w")
    for coe, grau in polinomio :
        sinal = ""
        if coe > 0 :
            sinal = "+"
            if coe in polinomio[0]:
                sinal = ""
        if coe == 1 :
            registo = "x^"+str(grau)
        else: registo = str(coe)+"x^"+str(grau)
        escrito = sinal + registo
        file.write(escrito)
    file.close()
    return 

   
#LEITURA POLINOMIO
def leiturapoli(p):
    for coe,grau in p:
        print((coe,grau)) 

#CÁLCULO DERIVADA
def derivada(p):
    pd =[]
    for coe, grau in p: 
        if grau == int(0) :
            coe = 0 
            pd.append((coe,grau))
        elif coe == 3.7 :
            coe = 14.8
            grau = grau - 1 
            pd.append ((coe, grau))
        else: 
            coe = int(float(coe)) * int(grau)
            grau = (int(grau)) - 1 
            pd.append((coe,grau))
    return pd
                
#SOMA POLINÓMIOS 
def somapoli (pa,pb) :
    psoma = pa + pb
    for polinomio2 in pb:
        for polinomio in pa:

            if polinomio[1] == polinomio2[1] :
                coesoma = int(float(polinomio[0])) + int(polinomio2[0])
                psoma.append((coesoma, polinomio[1]))
                if polinomio2 in psoma : 
                    psoma.remove(polinomio2)
                if polinomio in psoma :   
                    psoma.remove(polinomio)
    return psoma




#DESENHO GRÁFICO
def pot(a,b):
    res = 1
    while b > 0:
        res = res * a
        b = b - 1 
    return res 
    
def calcPolinomio(p, x):
    res = 0 
    for termo in p:
        c = termo[0]
        g = termo[1]
        res = res + c * pot(x, g)
    return res

import matplotlib.pyplot as plt 
def desenharpoli (p) :
    valx = []
    valy = []
    for x in range (0,11):
        valx.append(x)
        y = calcPolinomio(p,x)
        valy.append(y)
    
    plt.plot(valx,valy, color="green")
    plt.xlabel("Abcissas")
    plt.ylabel("Ordenadas")
    plt.title("Polinómio")
    plt.show()

# %%
#PARTE 3
def criarpoli() :
    polinomio = []
    grau = int(input("Qual o grau que deseja que o polinómio tenha?"))
    n = grau 
    while n != 0:
        coe = int(input("Qual é o coeficiente para o grau " + str(n) + "?"))
        polinomio.append((coe,n))
        n = n - 1
    return polinomio
    

def listar(file) :
    n = 0
    file = open(file,"r")
    print( "                   POLINÓMIOS                     ")
    print("---------------------------------------------------")
    for line in file :
        line = line.strip("\n")
        polinomios = line.split(" ; ")
        n += 1
        for polinomio in polinomios :
            if polinomio[1] == "." :
                coe = 3.7
            elif polinomio[1] != ",":
                coe = polinomio[:2]
            else: coe = polinomio[0]
            if polinomio[-1] != "0" :
                grau = polinomio[-1]
                print("Polinómio " + str(n) + "  |   " + str(coe) + "x^" + str(grau))

            else: print ("Polinómio " + str(n) + "  |   " + str(coe) + "x")
     
    

#CALCULAR NUM PONTO
def polinomioencontrar(file, n):
    file = open(file,"r")
    m = int(n) - 1
    for line in file :
        line = line.strip("\n")
        polinomios = line.split(" ; ")
        print(polinomios)
        polinomiodesejado = polinomios[m]
        return polinomiodesejado

def pot (a,b) :
    if b == 1: return a 
    else: return a* pot(a, b-1)


def calcularponto (n) :
    x = int(input("Qual deseja que seja o seu x?"))
    polinomiocalcular = polinomioencontrar("polinomiostpc.txt", n)
    print(polinomiocalcular)
    res1 = pot(x, int(polinomiocalcular[-1]))
    print(res1)
    res = res1 * (polinomiocalcular[0])
    print(polinomiocalcular[0])
    print(res)
    return ("O ponto calculado no polinómio número " + str(n)+ " quando x = " + str(x) + " é igual a: " + str(res))



#LISTAR COM GRAU

def listagrau (fnome) :
    n = 1
    file = open(fnome,"r")
    print( "  ORDEM               |||                 POLINÓMIOS       ||               GRAU              ")
    print("------------------------------------------------------------------------------------------------")
    for line in file :
        line = line.strip("\n")
        polinomios = line.split(" ; ")

        for polinomio in polinomios :
            if polinomio[1] == "." :
                coe = 3.7
            elif polinomio[1] != ",":
                coe = polinomio[:2]
            else: coe = polinomio[0]
            if polinomio[-1] != "0" :
                grau = polinomio[-1]
                print("Polinómio " + str(n) + "           |||   " + str(coe) + "x^" + str(grau) + "                            |||         " + str(grau))

            else: print ("Polinómio " + str(n) + "           |||   " + str(coe) + "                              |||         " + str(grau))
            n += 1     



#MAIOR GRAU

def maiorgrau(fnome):
    maiorgrau = 0
    file = open(fnome,"r")

    for line in file :
        line = line.strip("\n")
        polinomios = line.split(" ; ")
#        print(polinomios)
        for m in range (0, len(polinomios)-1):

            if int(polinomios[m][-1] )> maiorgrau :
                maiorgrau = int(polinomios[m][-1])
                l = m + 1
            else: 
                maiorgrau = maiorgrau
                l = l
        return print("O maior grau é " + str(maiorgrau) + " sendo o polinómio de ordem " + str(l))


#DERIVADA

def derivada(fnome):
    print( "  POLINÓMIO               |||                 DERVIVADA ")
    print("---------------------------------------------------------")
    file = open(fnome,"r")
    for line in file :
        line = line.strip("\n")
        polinomios = line.split(" ; ")
  
        for m in range (0, len(polinomios)):
            res= []
            coe = int(polinomios[m][0])
            grau = int(polinomios[m][-1])
            p = coe, grau
            if int(polinomios[m][-1]) != 0 :
                grau = int(polinomios[m][-1]) - 1
                coe = int(polinomios[m][-1]) * int(polinomios[m][0])
                res.append((coe,grau))
            else: res.append((0,0))
            print(str(polinomios[m] + "                      |||     " + str(res)))
    file.close()
    
    




menu = print("Que opção deseja? \n 0. Sair do menu; \n 1. Criar um polinómio; \n 2. Listar os polinómios disponíveis; \n 3. Calcular o valor de um ponto num polinómio; \n 4. Listar os polinómios com os seus graus; \n 5. Mostra o polinómio de maior grau; \n 6. Mostrar as derivadas de cada polinómio listado.")
menu
n = int(input("Qual a opção que deseja?"))
while n != 0: 
    if n == 1 :
        criarpoli()
        n = int(input("Qual a opção que deseja?"))

    elif n == 2: 
        listar("polinomiostpc.txt")
        n = int(input("Qual a opção que deseja?"))

    elif n == 3 :
        ordem = input("Qual o número do polinómio que deseja utilizar?")
        calcularponto(ordem)
        n = int(input("Qual a opção que deseja?"))

    elif n == 4 :
        listagrau("polinomiostpc.txt")
        n = int(input("Qual a opção que deseja?"))

    elif n == 5 :
        maiorgrau("polinomiostpc.txt")
        n = int(input("Qual a opção que deseja?"))

    elif n == 6 : 
        derivada("polinomiostpc.txt")
        n = int(input("Qual a opção que deseja?"))

    else: 
        print("Não selecionou nenhuma opção válida! Tente de novo.")
        n = int(input("Qual a opção que deseja?"))

print("Acabou o programa!")
# Out:
# Que opção deseja?
#  0. Sair do menu;
#  1. Criar um polinómio;
#  2. Listar os polinómios disponíveis;
#  3. Calcular o valor de um ponto num polinómio;
#  4. Listar os polinómios com os seus graus;
#  5. Mostra o polinómio de maior grau;
#  6. Mostrar as derivadas de cada polinómio listado.
#   ORDEM               |||                 POLINÓMIOS       ||               GRAU
# ------------------------------------------------------------------------------------------------
# Polinómio 1           |||   1x^7                            |||         7
# Polinómio 2           |||   3.7x^4                            |||         4
# Polinómio 3           |||   5x^3                            |||         3
# Polinómio 4           |||   88                              |||         3
# Polinómio 5           |||   2x^2                            |||         2
# Polinómio 6           |||   17                              |||         2
# ...
