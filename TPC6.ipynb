# %% [markdown]
# ### TPC6: Análise de dados: doença cardíaca
#
# Descarregue o ficheiro de dados: [diabetes_prediction_dataset.csv](./datasets/diabetes_prediction_dataset.csv.zip).
#
# Encontra mais informação sobre este conjunto de dados [aqui](https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset).
#
# Crie um programa em Python, conjunto de funções, que responda às seguintes questões:
# * Crie uma função que lê a informação do ficheiro para um modelo, previamente pensado em memória;
# * Crie uma função que calcula a distribuição da doença por sexo (tenha atenção que indivíduos doentes e não doentes no dataset);
# * Crie uma função que calcula a distribuição da doença por escalões etários. Considere os seguintes escalões: [0-10], [11-24], [25-29], [30-34], [35-39], [40-44], ...
# * Crie uma função que calcula a distribuição da doença por níveis de glucose. Considere um nível igual a um intervalo de 10 unidades, comece no limite inferior e crie os níveis necessários até abranger o limite superior;
# * Crie uma função que imprime na forma de uma tabela uma distribuição;
# * Especifique um programa que ao executar apresenta as tabelas correspondentes às distribuições pedidas.

# %%
#Função ler a informação do ficheiro.
def lerFicheiro(fnome):
    return open(fnome, 'r')

#Função calcular a distribuição da doença por sexo.
def distribuicaodoenca (fnome):

    f = lerFicheiro(fnome)
    linhas = f.readlines()

    diabeteshomem = []
    homens = []
    diabetesmulher = []
    mulheres = []

    for linha in linhas :

        campos = linha.strip().split(",")

        if campos[8] == '1' :

            if campos[0] == str("Male") :
                diabeteshomem.append(1)

            elif campos[0] == str("Female") :
                diabetesmulher.append(1)

        if campos[0] == str("Male") :
            homens.append(1)    

        elif campos[0] == str("Female") :
            mulheres.append(1)

    Nmulheresd = len(diabetesmulher)
    Nhomensd = len(diabeteshomem)
    nmulheres = len(mulheres)
    nhomens = len (homens)

    print(Nhomensd , "homens de", nhomens, "homens têm diabetes.")
    print(Nmulheresd , "mulheres de", nmulheres, "mulheres têm diabetes.")
 
#Função calcular a distribuição da doença por escalões etários.
#1:[0-10], 2:[11-20], 3:[21-30], 4:[31-40], 5:[41-50], 6:[51-60], 7:[61,70], 8:[71,80]
def escaloesetarios (fnome) :
    f = lerFicheiro(fnome)
    linhas = f.readlines()

    dis1 = []
    dis2 = []
    dis3 = []
    dis4 = []
    dis5 = []
    dis6 = []
    dis7 = []
    dis8 = []

    for linha in linhas:
        campos = linha.strip().split(",")
        campos[1] = int(float(campos[1]))
        campos[8] = int(campos[8])
        if campos[8] == 1:
            if campos[1] in range(0, 11):
                dis1.append(1)
            elif campos[1] in range(21, 31):
                dis2.append(1)
            elif campos[1] in range(31, 41):
                dis3.append(1)
            elif campos[1] in range(41, 51):
                dis4.append(1)
            elif campos[1] in range(51, 61):
                dis5.append(1)
            elif campos[1] in range(61, 71):
                dis6.append(1)
            elif campos[1] in range(71, 81):
                dis7.append(1)
            elif campos[1] in range(11, 21):
                dis8.append(1)

    print("Nas idades entre [0-10] anos, existem", len(dis1), "doentes.")
    print("Nas idades entre [11-20] anos, existem", len(dis2), "doentes.")
    print("Nas idades entre [21-30] anos, existem", len(dis3), "doentes.")
    print("Nas idades entre [31-40] anos, existem", len(dis4), "doentes.")
    print("Nas idades entre [41-50] anos, existem", len(dis5), "doentes.")
    print("Nas idades entre [51-60] anos, existem", len(dis6), "doentes.")
    print("Nas idades entre [61-70] anos, existem", len(dis7), "doentes.")
    print("Nas idades entre [71-80] anos, existem", len(dis8), "doentes.")
        
#Função calcular a distribuição da doença por níveis de glucose.
#1:[80-90], 2:[91-100], 3:[101-110], 4:[111-1], 5:[41-50], 6:[51-60], 7:[61,70], 8:[71,80]
def glucosedis (fnome) :
    f = lerFicheiro(fnome)
    linhas = f.readlines()

    dis1 = []
    dis2 = []
    dis3 = []
    dis4 = []
    dis5 = []
    dis6 = []
    dis7 = []
    dis8 = []       
    dis9 = []
    dis10 = []
    dis11 = []
    dis12 = []
    dis13 = []
    dis14 = []
    dis15 = []
    dis16 = []
    dis17 = []
    dis18 = []
    dis19 = []
    dis20 = []
    dis21 = []
    dis22 = []

    for linha in linhas:
        campos = linha.strip().split(",")
        campos[7] = int(campos[7])
        campos[8] = int(campos[8])
        if campos[8] == 1:
            if campos[7] <= 90:
                dis1.append(1)
            elif campos[7] in range (91,101):
                dis2.append(1)
            elif campos[7] in range (101,111):
                dis3.append(1)
            elif campos[7] in range (111,121):
                dis22.append(1)                    
            elif campos[7] in range (121, 131):
                dis4.append(1)
            elif campos[7] in range (131, 141):
                dis5.append(1)
            elif campos[7] in range (141, 151):
                dis6.append(1)
            elif campos[7] in range (151,161):
                dis7.append(1)               
            elif campos[7] in range (161,171):
                dis8.append(1)
            elif campos[7] in range (171,181):
                dis9.append(1)
            elif campos[7] in range (181,191):
                dis10.append(1)
            elif campos[7] in range (191,201):
                dis11.append(1)
            elif campos[7] in range (201,211):
                dis12.append(1)
            elif campos[7] in range (211,221):
                dis13.append(1)    
            elif campos[7] in range (221,231):
                dis14.append(1)
            elif campos[7] in range (231,241):
                dis15.append(1)
            elif campos[7] in range (241,251):
                dis16.append(1)
            elif campos[7] in range (251,261):
                dis17.append(1)
            elif campos[7] in range (261,271):
                di18.append(1)
            elif campos[7] in range (271,281):
                dis19.append(1)               
            elif campos[7] in range (281,291):
                dis20.append(1)
            elif campos[7] in range (291,301):
                dis21.append(1)
    
    print("Nos níveis glucólicos entre [80-90], existem", len(dis1), "doentes.")
    print("Nos níveis glucólicos entre [91-100], existem", len(dis2), "doentes.")
    print("Nos níveis glucólicos entre [101-110], existem", len(dis3), "doentes.")
    print("Nos níveis glucólicos entre [111-120], existem", len(dis22), "doentes.")
    print("Nos níveis glucólicos entre [121-130], existem", len(dis4), "doentes.")
    print("Nos níveis glucólicos entre [131-140], existem", len(dis5), "doentes.")
    print("Nos níveis glucólicos entre [141-150], existem", len(dis6), "doentes.")
    print("Nos níveis glucólicos entre [151-160], existem", len(dis7), "doentes.")
    print("Nos níveis glucólicos entre [161-170], existem", len(dis8), "doentes.")
    print("Nos níveis glucólicos entre [171-180], existem", len(dis9), "doentes.")
    print("Nos níveis glucólicos entre [181-190], existem", len(dis10), "doentes.")
    print("Nos níveis glucólicos entre [191-200], existem", len(dis11), "doentes.")
    print("Nos níveis glucólicos entre [201-210], existem", len(dis12), "doentes.")
    print("Nos níveis glucólicos entre [211-220], existem", len(dis13), "doentes.")
    print("Nos níveis glucólicos entre [221-230], existem", len(dis14), "doentes.")
    print("Nos níveis glucólicos entre [231-240], existem", len(dis15), "doentes.")
    print("Nos níveis glucólicos entre [241-250], existem", len(dis16), "doentes.")
    print("Nos níveis glucólicos entre [251-260], existem", len(dis17), "doentes.")
    print("Nos níveis glucólicos entre [261-270], existem", len(dis18), "doentes.")
    print("Nos níveis glucólicos entre [271-280], existem", len(dis19), "doentes.")
    print("Nos níveis glucólicos entre [281-290], existem", len(dis20), "doentes.")
    print("Nos níveis glucólicos entre [291-300], existem", len(dis21), "doentes.")

# %%
Menu= "Bom dia! O que deseja verificar? \n (1) Distribuição da doença por sexo; \n (2) Distribuição da doença por faxa etária; \n (3) Distribuição da doença por níveis glucólicos; \n (4) Fechar menu."
print(Menu)

n = int(input("Escolha a opção que deseja."))

while n != 4 :
    if n == 1 :
        distribuicaodoenca("diabetes_prediction_dataset.csv")
        n = int(input("Escolha a opção que deseja."))

    if n == 2 :
        escaloesetarios ("diabetes_prediction_dataset.csv")
        n = int(input("Escolha a opção que deseja."))

    if n == 3 :
        glucosedis ("diabetes_prediction_dataset.csv")
        n = int(input("Escolha a opção que deseja."))
 
print("Até uma próxima!")
# Out:
# Bom dia! O que deseja verificar?
#  (1) Distribuição da doença por sexo;
#  (2) Distribuição da doença por faxa etária;
#  (3) Distribuição da doença por níveis glucólicos;
#  (4) Fechar menu.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\carol\Desktop\Programação\AULA6\Untitled-tpc.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/carol/Desktop/Programa%C3%A7%C3%A3o/AULA6/Untitled-tpc.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> Menu= "Bom dia! O que deseja verificar? \n (1) Distribuição da doença por sexo; \n (2) Distribuição da doença por faxa etária; \n (3) Distribuição da doença por níveis glucólicos; \n (4) Fechar menu."
#       <a href='vscode-notebook-cell:/c%3A/Users/carol/Desktop/Programa%C3%A7%C3%A3o/AULA6/Untitled-tpc.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> print(Menu)
# ...
